# %% [markdown]
# <a href="https://colab.research.google.com/github/nirmalaselvaraj963-sys/ml-work/blob/main/svr_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('/content/insurance_pre.csv')

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {
    'kernel': ['linear', 'rbf'],        # most useful kernels
    'C': [1, 10, 100],                 # typical values
    'gamma': ['scale', 'auto'],        # standard choices
    'epsilon': [0.1, 0.2]              # reasonable margins
}

grid = GridSearchCV(
    SVR(),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1
)

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100], 'epsilon': [0.1, 0.2],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf']},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# r2: 0.5938756684512585

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 18       0.132005      0.017197         0.017149        0.005368      100
# 16       0.119673      0.019104         0.019405        0.002734      100
# 20       0.092940      0.025646         0.012422        0.003361      100
# 22       0.080224      0.001410         0.010807        0.000264      100
# 12       0.139422      0.014943         0.020972        0.005066       10
# 14       0.126662      0.026769         0.021210        0.006193       10
# 10       0.124963      0.021211         0.020320        0.002548       10
# 8        0.069749      0.004548         0.011516        0.000059       10
# 19       0.119408      0.036607         0.030315        0.008750      100
# 23       0.086068      0.008357         0.023692        0.006761      100
# 17       0.130002      0.033704         0.035138        0.019229      100
# 21       0.082860      0.000938         0.022764        0.000780      100
# 0        0.067093      0.015552         0.013167        0.002059        1
# 2        0.064125      0.001014         0.011096        0.000323        1
# 6        0.064569      0.001880         0.012002        0.000438        1
# 4        0.064711      0.002318         0.013479        0.004403        1
# 15       0.156145      0.009445         0.046415        0.006000       10
# 13       0.168179      0.003346         0.045641        0.001778       10
# 9        0.093865      0.011285         0.032395        0.010336       10
# 11       0.122027      0.022658         0.040326        0.011523       10
# 7        0.080725      0.001959         0.025331        0.001513        1
# 3        0.087821      0.007922         0.024805        0.001036        1
# 1        0.081195      0.004232         0.024328        0.000764        1
# 5        0.092517      0.016004         0.024611        0.002551        1
#
#     param_epsilon param_gamma param_kernel  \
# 18            0.1        auto       linear
# 16            0.1       scale       linear
# 20            0.2       scale       linear
# 22            0.2        auto       linear
# 12            0.2       scale       linear
# 14            0.2        auto       linear
# 10            0.1        auto       linear
# 8             0.1       scale       linear
# 19            0.1        auto          rbf
# 23            0.2        auto          rbf
# 17            0.1       scale          rbf
# 21            0.2       scale          rbf
# 0             0.1       scale       linear
# 2             0.1        auto       linear
# 6             0.2        auto       linear
# 4             0.2       scale       linear
# 15            0.2        auto          rbf
# 13            0.2       scale          rbf
# 9             0.1       scale          rbf
# 11            0.1        auto          rbf
# 7             0.2        auto          rbf
# 3             0.1        auto          rbf
# 1             0.1       scale          rbf
# 5             0.2       scale          rbf
#
#                                                params  split0_test_score  \
# 18  {'C': 100, 'epsilon': 0.1, 'gamma': 'auto', 'k...           0.585412
# 16  {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', '...           0.585412
# 20  {'C': 100, 'epsilon': 0.2, 'gamma': 'scale', '...           0.585413
# 22  {'C': 100, 'epsilon': 0.2, 'gamma': 'auto', 'k...           0.585413
# 12  {'C': 10, 'epsilon': 0.2, 'gamma': 'scale', 'k...           0.390619
# 14  {'C': 10, 'epsilon': 0.2, 'gamma': 'auto', 'ke...           0.390619
# 10  {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'ke...           0.390629
# 8   {'C': 10, 'epsilon': 0.1, 'gamma': 'scale', 'k...           0.390629
# 19  {'C': 100, 'epsilon': 0.1, 'gamma': 'auto', 'k...           0.282882
# 23  {'C': 100, 'epsilon': 0.2, 'gamma': 'auto', 'k...           0.282879
# 17  {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', '...           0.282276
# 21  {'C': 100, 'epsilon': 0.2, 'gamma': 'scale', '...           0.282273
# 0   {'C': 1, 'epsilon': 0.1, 'gamma': 'scale', 'ke...          -0.022361
# 2   {'C': 1, 'epsilon': 0.1, 'gamma': 'auto', 'ker...          -0.022361
# 6   {'C': 1, 'epsilon': 0.2, 'gamma': 'auto', 'ker...          -0.022361
# 4   {'C': 1, 'epsilon': 0.2, 'gamma': 'scale', 'ke...          -0.022361
# 15  {'C': 10, 'epsilon': 0.2, 'gamma': 'auto', 'ke...          -0.037325
# 13  {'C': 10, 'epsilon': 0.2, 'gamma': 'scale', 'k...          -0.037397
# 9   {'C': 10, 'epsilon': 0.1, 'gamma': 'scale', 'k...          -0.037397
# 11  {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'ke...          -0.037325
# 7   {'C': 1, 'epsilon': 0.2, 'gamma': 'auto', 'ker...          -0.080389
# 3   {'C': 1, 'epsilon': 0.1, 'gamma': 'auto', 'ker...          -0.080389
# 1   {'C': 1, 'epsilon': 0.1, 'gamma': 'scale', 'ke...          -0.080400
# 5   {'C': 1, 'epsilon': 0.2, 'gamma': 'scale', 'ke...          -0.080400
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 18           0.629734           0.617429           0.584651
# 16           0.629734           0.617429           0.584651
# 20           0.629733           0.617418           0.584650
# 22           0.629733           0.617418           0.584650
# 12           0.478402           0.431260           0.387324
# 14           0.478402           0.431260           0.387324
# 10           0.478401           0.431247           0.387305
# 8            0.478401           0.431247           0.387305
# 19           0.365482           0.289946           0.246873
# 23           0.365481           0.289944           0.246876
# 17           0.365919           0.290460           0.247487
# 21           0.365919           0.290458           0.247490
# 0            0.039058          -0.015690          -0.061454
# 2            0.039058          -0.015690          -0.061454
# 6            0.039060          -0.015690          -0.061454
# 4            0.039060          -0.015690          -0.061454
# 15           0.021048          -0.036168          -0.084435
# 13           0.021106          -0.036096          -0.084348
# 9            0.021106          -0.036096          -0.084348
# 11           0.021048          -0.036168          -0.084435
# 7           -0.031652          -0.080293          -0.132101
# 3           -0.031652          -0.080293          -0.132101
# 1           -0.031645          -0.080285          -0.132092
# 5           -0.031645          -0.080285          -0.132092
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 18           0.552153         0.593876        0.027343                1
# 16           0.552153         0.593876        0.027343                1
# 20           0.552155         0.593874        0.027340                3
# 22           0.552155         0.593874        0.027340                3
# 12           0.354880         0.408497        0.042538                5
# 14           0.354880         0.408497        0.042538                5
# 10           0.354880         0.408492        0.042537                7
# 8            0.354880         0.408492        0.042537                7
# 19           0.215599         0.280156        0.050317                9
# 23           0.215597         0.280155        0.050317               10
# 17           0.214634         0.280155        0.050649               11
# 21           0.214631         0.280154        0.050649               12
# 0           -0.097104        -0.031510        0.045854               13
# 2           -0.097104        -0.031510        0.045854               13
# 6           -0.097105        -0.031510        0.045855               15
# 4           -0.097105        -0.031510        0.045855               15
# 15          -0.117452        -0.050866        0.047184               17
# 13          -0.117599        -0.050867        0.047231               18
# 9           -0.117601        -0.050867        0.047232               19
# 11          -0.117458        -0.050867        0.047186               20
# 7           -0.163512        -0.097589        0.045781               21
# 3           -0.163512        -0.097589        0.045781               21
# 1           -0.163526        -0.097589        0.045786               23
# 5           -0.163526        -0.097589        0.045786               23

# %%
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
load_model=pickle.load(open("/content/RF_G.sav","rb"))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:24
# BMI:22
# Children:0
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[101827.35753032]
