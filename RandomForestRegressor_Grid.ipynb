# %% [markdown]
# <a href="https://colab.research.google.com/github/nirmalaselvaraj963-sys/ml-work/blob/main/RandomForestRegressor_Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('/content/insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'n_estimators': [10, 20, 30, 100],
    'max_depth': [None, 10, 20, 30],
    'max_features': ['sqrt', 'log2'],
    #min_samples_split': [2, 5, 10],
    #min_samples_leaf': [1, 2, 4],
    #bootstrap': [True, False]
}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 20, 30, 100]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# r2: 0.8244089923957745

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 11       0.369674      0.007905         0.023881        0.001074
# 15       0.654042      0.083492         0.045689        0.009657
# 3        0.413864      0.027275         0.024557        0.000931
# 13       0.093999      0.018114         0.009889        0.002785
# 27       0.410191      0.012526         0.029418        0.010069
# 19       0.413002      0.009047         0.023518        0.000962
# 10       0.123510      0.011665         0.011148        0.001999
# 14       0.194996      0.029222         0.016448        0.006458
# 9        0.080730      0.003461         0.007447        0.000632
# 31       0.385418      0.040549         0.022763        0.004800
# 23       0.430274      0.022732         0.027041        0.003022
# 7        0.439776      0.029535         0.028959        0.004749
# 1        0.079956      0.000817         0.007263        0.000541
# 2        0.122919      0.004445         0.009778        0.000976
# 30       0.123311      0.002081         0.009506        0.000526
# 18       0.202623      0.040321         0.014861        0.006609
# 25       0.084408      0.001898         0.007805        0.000763
# 6        0.123094      0.003308         0.009726        0.000648
# 22       0.123423      0.005930         0.010923        0.002078
# 26       0.139883      0.011982         0.013252        0.003799
# 0        0.057002      0.008320         0.006472        0.001395
# 29       0.085307      0.003855         0.007196        0.000159
# 21       0.091276      0.012710         0.008141        0.001010
# 5        0.096099      0.013859         0.008968        0.001198
# 12       0.046303      0.013173         0.007352        0.004289
# 20       0.042024      0.000624         0.004999        0.000091
# 24       0.046079      0.001438         0.005296        0.000423
# 8        0.041937      0.002395         0.005339        0.000320
# 17       0.152808      0.019598         0.015000        0.005592
# 4        0.041451      0.001264         0.004988        0.000108
# 16       0.080082      0.020197         0.012782        0.004600
# 28       0.043446      0.001267         0.005330        0.000250
#
#    param_max_depth param_max_features  param_n_estimators  \
# 11              10               sqrt                 100
# 15              10               log2                 100
# 3             None               sqrt                 100
# 13              10               log2                  20
# 27              30               sqrt                 100
# 19              20               sqrt                 100
# 10              10               sqrt                  30
# 14              10               log2                  30
# 9               10               sqrt                  20
# 31              30               log2                 100
# 23              20               log2                 100
# 7             None               log2                 100
# 1             None               sqrt                  20
# 2             None               sqrt                  30
# 30              30               log2                  30
# 18              20               sqrt                  30
# 25              30               sqrt                  20
# 6             None               log2                  30
# 22              20               log2                  30
# 26              30               sqrt                  30
# 0             None               sqrt                  10
# 29              30               log2                  20
# 21              20               log2                  20
# 5             None               log2                  20
# 12              10               log2                  10
# 20              20               log2                  10
# 24              30               sqrt                  10
# 8               10               sqrt                  10
# 17              20               sqrt                  20
# 4             None               log2                  10
# 16              20               sqrt                  10
# 28              30               log2                  10
#
#                                                params  split0_test_score  \
# 11  {'max_depth': 10, 'max_features': 'sqrt', 'n_e...           0.854025
# 15  {'max_depth': 10, 'max_features': 'log2', 'n_e...           0.850822
# 3   {'max_depth': None, 'max_features': 'sqrt', 'n...           0.847103
# 13  {'max_depth': 10, 'max_features': 'log2', 'n_e...           0.861414
# 27  {'max_depth': 30, 'max_features': 'sqrt', 'n_e...           0.848415
# 19  {'max_depth': 20, 'max_features': 'sqrt', 'n_e...           0.845669
# 10  {'max_depth': 10, 'max_features': 'sqrt', 'n_e...           0.853011
# 14  {'max_depth': 10, 'max_features': 'log2', 'n_e...           0.852627
# 9   {'max_depth': 10, 'max_features': 'sqrt', 'n_e...           0.849624
# 31  {'max_depth': 30, 'max_features': 'log2', 'n_e...           0.844920
# 23  {'max_depth': 20, 'max_features': 'log2', 'n_e...           0.848750
# 7   {'max_depth': None, 'max_features': 'log2', 'n...           0.843627
# 1   {'max_depth': None, 'max_features': 'sqrt', 'n...           0.849350
# 2   {'max_depth': None, 'max_features': 'sqrt', 'n...           0.847639
# 30  {'max_depth': 30, 'max_features': 'log2', 'n_e...           0.843824
# 18  {'max_depth': 20, 'max_features': 'sqrt', 'n_e...           0.848228
# 25  {'max_depth': 30, 'max_features': 'sqrt', 'n_e...           0.839480
# 6   {'max_depth': None, 'max_features': 'log2', 'n...           0.845483
# 22  {'max_depth': 20, 'max_features': 'log2', 'n_e...           0.837939
# 26  {'max_depth': 30, 'max_features': 'sqrt', 'n_e...           0.846833
# 0   {'max_depth': None, 'max_features': 'sqrt', 'n...           0.826537
# 29  {'max_depth': 30, 'max_features': 'log2', 'n_e...           0.832330
# 21  {'max_depth': 20, 'max_features': 'log2', 'n_e...           0.843922
# 5   {'max_depth': None, 'max_features': 'log2', 'n...           0.845532
# 12  {'max_depth': 10, 'max_features': 'log2', 'n_e...           0.828004
# 20  {'max_depth': 20, 'max_features': 'log2', 'n_e...           0.835222
# 24  {'max_depth': 30, 'max_features': 'sqrt', 'n_e...           0.840407
# 8   {'max_depth': 10, 'max_features': 'sqrt', 'n_e...           0.812897
# 17  {'max_depth': 20, 'max_features': 'sqrt', 'n_e...           0.834681
# 4   {'max_depth': None, 'max_features': 'log2', 'n...           0.832945
# 16  {'max_depth': 20, 'max_features': 'sqrt', 'n_e...           0.821118
# 28  {'max_depth': 30, 'max_features': 'log2', 'n_e...           0.822896
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 11           0.829250           0.815481           0.845605
# 15           0.833228           0.808544           0.848287
# 3            0.823454           0.805050           0.837390
# 13           0.817268           0.809812           0.834145
# 27           0.826619           0.802132           0.837992
# 19           0.827383           0.808351           0.835653
# 10           0.826124           0.801789           0.845879
# 14           0.820478           0.807685           0.835428
# 9            0.823694           0.811407           0.831294
# 31           0.823407           0.804580           0.835892
# 23           0.822573           0.801282           0.838046
# 7            0.823822           0.798005           0.837628
# 1            0.822786           0.790736           0.831209
# 2            0.820970           0.792126           0.837682
# 30           0.823302           0.804213           0.830433
# 18           0.819281           0.796986           0.828335
# 25           0.822606           0.799308           0.830996
# 6            0.817034           0.795591           0.828416
# 22           0.813661           0.791050           0.835021
# 26           0.815402           0.794377           0.830793
# 0            0.816505           0.818141           0.816450
# 29           0.813256           0.798217           0.828515
# 21           0.813035           0.793084           0.831296
# 5            0.808658           0.788247           0.823522
# 12           0.820700           0.788785           0.825295
# 20           0.799892           0.797188           0.824298
# 24           0.800183           0.785315           0.831926
# 8            0.819572           0.792998           0.836043
# 17           0.810306           0.784728           0.816643
# 4            0.803448           0.780165           0.829859
# 16           0.801172           0.776820           0.824663
# 28           0.798860           0.776799           0.807910
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 11           0.777683         0.824409        0.026881                1
# 15           0.771220         0.822420        0.029687                2
# 3            0.777940         0.818187        0.024597                3
# 13           0.767775         0.818083        0.030775                4
# 27           0.772365         0.817505        0.027321                5
# 19           0.767903         0.816992        0.027434                6
# 10           0.758064         0.816973        0.034406                7
# 14           0.768257         0.816895        0.028578                8
# 9            0.767247         0.816653        0.027639                9
# 31           0.772868         0.816333        0.025601               10
# 23           0.768578         0.815846        0.028521               11
# 7            0.772408         0.815098        0.026504               12
# 1            0.776338         0.814084        0.026768               13
# 2            0.770220         0.813727        0.028760               14
# 30           0.765574         0.813469        0.027150               15
# 18           0.766581         0.811882        0.028002               16
# 25           0.764397         0.811357        0.027032               17
# 6            0.767464         0.810798        0.027061               18
# 22           0.774312         0.810397        0.024706               19
# 26           0.763626         0.810206        0.029026               20
# 0            0.767153         0.808957        0.021233               21
# 29           0.763318         0.807127        0.025015               22
# 21           0.749794         0.806226        0.033024               23
# 5            0.757508         0.804693        0.030116               24
# 12           0.759597         0.804476        0.026497               25
# 20           0.763110         0.803942        0.024989               26
# 24           0.753147         0.802195        0.031745               27
# 8            0.743535         0.801009        0.031877               28
# 17           0.757330         0.800737        0.026971               29
# 4            0.751854         0.799654        0.030659               30
# 16           0.766123         0.797979        0.023324               31
# 28           0.751939         0.791681        0.024860               32

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename = "DecisionTreeRegressor.sav"
pickle.dump(grid.best_estimator_, open(filename, 'wb'))

# %%
load_model=pickle.load(open("/content/DecisionTreeRegressor.sav","rb"))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:24
# BMI:22
# Children:0
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[15479.68998801]
